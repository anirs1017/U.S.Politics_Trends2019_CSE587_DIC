# %% [markdown]
# ## DIC Lab 2 - Common Crawl Data Extraction
#
# Submitted by Aniruddha Sinha (asinha6@buffalo.edu, 50289428) and Shashank Dhar (sdhar2@buffalo.edu, 50289718)

# %% [markdown]
# ### Import the necessary librariers

# %%
import requests
import argparse
import time
import json
import StringIO
import gzip
import csv
import codecs
import csv

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### Domain for Common Crawl is www.huffpost.com - has abundant data on political affairs and activities. Index chosen in Week 13 of 2019.

# %%
domain = 'https://www.huffpost.com/news/politics'
index_list = ["2019-13"]

# %% [markdown]
# ### Function to scrape data on the particular domain and obtain records

# %%
def searchInDomain(domain):
    CC_records = []
    
#     print "\n\nSearching content in %s domain" %domain
    
    for index in index_list:
#         print "\nSeeking data from domain: %s" %domain
        
        cc_url = "http://index.commoncrawl.org/CC-MAIN-%s-index?" %index
        cc_url += "url=%s&matchType=domain&output=json" %domain
        
        response = requests.get(cc_url)
        
        if response.status_code == 200:
            records = response.content.splitlines()
            
            for record in records:
                CC_records.append(json.loads(record))
                
#             print "\nAdded %d results." %len(records)
            
#         print "\n\n\n"
#     print "\nTotal hits = %d on domain ." %len(CC_records)
    
    return CC_records

# %% [markdown]
# ### Following function visits AWS's Common Crawl repository to download all the HTML content scraped so far for the particular domain. Further, the content is extracted from the gzip format in which it is stored, cleaned and passed as a response to the next function that extracts all related links from the page.

# %%
def download_htmlPage(record):

    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1
    
    cc_aws_address = 'https://commoncrawl.s3.amazonaws.com/'

    aws_response = requests.get(cc_aws_address + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
    raw_data = StringIO.StringIO(aws_response.content)
    f = gzip.GzipFile(fileobj=raw_data)
    pageData = f.read()
    
    response = ""

    if len(pageData):
        try:
            warc, header, response = pageData.strip().split('\r\n\r\n', 2)
        except:
            pass
        
    return response

# %% [markdown]
# ### Following function takes the page content from all HTML pages extracted from the Common Crawl repository, passes it to Beautiful Soup to convert it to json content and finds all the links related to the domain name. It returns a list of all such links obtained.

# %%
def extractAllExternalLinks(page_content, links):
    
    parser = BeautifulSoup(page_content)
    
#     print "\n\nRunning extractAllExternalLinks"
    found_links = parser.find_all("a")
    
    if found_links:
        for link in found_links:
            href = link.attrs.get("href")
            
            if (href is not None) and (domain not in href) and (href not in links):
                if href.startswith("http"):
#                     print "\nFound external domain link: %s" %href
                    links.append(href)
    
#     print "\n Exiting extract_external_links"
    return links

# %% [markdown]
# ### Following function finally writes the links to a CSV file row by row.

# %%
def writeToCSV(links):
    count = 0
    with codecs.open("politics_US_CC.csv", "a", encoding="utf-8") as output:
        fields = ["URL"]

        logger = csv.DictWriter(output, fieldnames=fields)
        logger.writeheader()

        for link in links:
            logger.writerow({"URL":link})
            if count >= 1500:
                break
            count += 1

# %% [markdown]
# ### We start calling the functions to get the Common Crawl Data.

# %%
all_records = searchInDomain(domain)
links = []
check = 0

# %% [markdown]
# ### Get data for a certain number of records found from searching the domain. We check for 5000 records. Also, we write the URLs to a CSV file.

# %%
for i in range(1500):
    record = all_records[i]
    
    page_content = download_htmlPage(record)
#     print "[*] Retrieved %d bytes for %s" %(len(page_content), record['url'])  
    links = extractAllExternalLinks(page_content, links)
    check += 1
    print "\n\nRUNNING ", check, " iteration."
    
print "Total domain related links discovered: %d" %len(links)

writeToCSV(links)
# Out:
# RUNNING  1  iteration.
#
#
# RUNNING  2  iteration.
#
#
# RUNNING  3  iteration.
#
#
# RUNNING  4  iteration.
#
#
# RUNNING  5  iteration.
#
#
# RUNNING  6  iteration.
#
#
# RUNNING  7  iteration.
#
#
# RUNNING  8  iteration.
#
#
# RUNNING  9  iteration.
#
#
# RUNNING  10  iteration.
#
#
# RUNNING  11  iteration.
#
#
# RUNNING  12  iteration.
#
#
# RUNNING  13  iteration.
#
#
# RUNNING  14  iteration.
#
#
# RUNNING  15  iteration.
#
#
# RUNNING  16  iteration.
#
#
# RUNNING  17  iteration.
#
#
# RUNNING  18  iteration.
#
#
# RUNNING  19  iteration.
#
#
# RUNNING  20  iteration.
#
#
# RUNNING  21  iteration.
#
#
# RUNNING  22  iteration.
#
#
# RUNNING  23  iteration.
#
#
# RUNNING  24  iteration.
#
#
# RUNNING  25  iteration.
#
#
# RUNNING  26  iteration.
#
#
# RUNNING  27  iteration.
#
#
# RUNNING  28  iteration.
#
#
# RUNNING  29  iteration.
#
#
# RUNNING  30  iteration.
#
#
# RUNNING  31  iteration.
#
#
# RUNNING  32  iteration.
#
#
# RUNNING  33  iteration.
#
#
# RUNNING  34  iteration.
#
#
# RUNNING  35  iteration.
#
#
# RUNNING  36  iteration.
#
#
# RUNNING  37  iteration.
#
#
# RUNNING  38  iteration.
#
#
# RUNNING  39  iteration.
#
#
# RUNNING  40  iteration.
#
#
# RUNNING  41  iteration.
#
#
# RUNNING  42  iteration.
#
#
# RUNNING  43  iteration.
#
#
# RUNNING  44  iteration.
#
#
# RUNNING  45  iteration.
#
#
# RUNNING  46  iteration.
#
#
# RUNNING  47  iteration.
#
#
# RUNNING  48  iteration.
#
#
# RUNNING  49  iteration.
#
#
# RUNNING  50  iteration.
#
#
# RUNNING  51  iteration.
#
#
# RUNNING  52  iteration.
#
#
# RUNNING  53  iteration.
#
#
# RUNNING  54  iteration.
#
#
# RUNNING  55  iteration.
#
#
# RUNNING  56  iteration.
#
#
# RUNNING  57  iteration.
#
#
# RUNNING  58  iteration.
#
#
# RUNNING  59  iteration.
#
#
# RUNNING  60  iteration.
#
#
# RUNNING  61  iteration.
#
#
# RUNNING  62  iteration.
#
#
# RUNNING  63  iteration.
#
#
# RUNNING  64  iteration.
#
#
# RUNNING  65  iteration.
#
#
# RUNNING  66  iteration.
#
#
# RUNNING  67  iteration.
#
#
# RUNNING  68  iteration.
#
#
# RUNNING  69  iteration.
#
#
# RUNNING  70  iteration.
#
#
# RUNNING  71  iteration.
#
#
# RUNNING  72  iteration.
#
#
# RUNNING  73  iteration.
#
#
# RUNNING  74  iteration.
#
#
# RUNNING  75  iteration.
#
#
# RUNNING  76  iteration.
#
#
# RUNNING  77  iteration.
#
#
# RUNNING  78  iteration.
#
#
# RUNNING  79  iteration.
#
#
# RUNNING  80  iteration.
#
#
# RUNNING  81  iteration.
#
#
# RUNNING  82  iteration.
#
#
# RUNNING  83  iteration.
#
#
# RUNNING  84  iteration.
#
#
# RUNNING  85  iteration.
#
#
# RUNNING  86  iteration.
#
#
# RUNNING  87  iteration.
#
#
# RUNNING  88  iteration.
#
#
# RUNNING  89  iteration.
#
#
# RUNNING  90  iteration.
#
#
# RUNNING  91  iteration.
#
#
# RUNNING  92  iteration.
#
#
# RUNNING  93  iteration.
#
#
# RUNNING  94  iteration.
#
#
# RUNNING  95  iteration.
#
#
# RUNNING  96  iteration.
#
#
# RUNNING  97  iteration.
#
#
# RUNNING  98  iteration.
#
#
# RUNNING  99  iteration.
#
#
# RUNNING  100  iteration.
#
#
# RUNNING  101  iteration.
#
#
# RUNNING  102  iteration.
#
#
# RUNNING  103  iteration.
#
#
# RUNNING  104  iteration.
#
#
# RUNNING  105  iteration.
#
#
# RUNNING  106  iteration.
#
#
# RUNNING  107  iteration.
#
#
# RUNNING  108  iteration.
#
#
# RUNNING  109  iteration.
#
#
# RUNNING  110  iteration.
#
#
# RUNNING  111  iteration.
#
#
# RUNNING  112  iteration.
#
#
# RUNNING  113  iteration.
#
#
# RUNNING  114  iteration.
#
#
# RUNNING  115  iteration.
#
#
# RUNNING  116  iteration.
#
#
# RUNNING  117  iteration.
#
#
# RUNNING  118  iteration.
#
#
# RUNNING  119  iteration.
#
#
# RUNNING  120  iteration.
#
#
# RUNNING  121  iteration.
#
#
# RUNNING  122  iteration.
#
#
# RUNNING  123  iteration.
#
#
# RUNNING  124  iteration.
#
#
# RUNNING  125  iteration.
#
#
# RUNNING  126  iteration.
#
#
# RUNNING  127  iteration.
#
#
# RUNNING  128  iteration.
#
#
# RUNNING  129  iteration.
#
#
# RUNNING  130  iteration.
#
#
# RUNNING  131  iteration.
#
#
# RUNNING  132  iteration.
#
#
# RUNNING  133  iteration.
#
#
# RUNNING  134  iteration.
#
#
# RUNNING  135  iteration.
#
#
# RUNNING  136  iteration.
#
#
# RUNNING  137  iteration.
#
#
# RUNNING  138  iteration.
#
#
# RUNNING  139  iteration.
#
#
# RUNNING  140  iteration.
#
#
# RUNNING  141  iteration.
#
#
# RUNNING  142  iteration.
#
#
# RUNNING  143  iteration.
#
#
# RUNNING  144  iteration.
#
#
# RUNNING  145  iteration.
#
#
# RUNNING  146  iteration.
#
#
# RUNNING  147  iteration.
#
#
# RUNNING  148  iteration.
#
#
# RUNNING  149  iteration.
#
#
# RUNNING  150  iteration.
#
#
# RUNNING  151  iteration.
#
#
# RUNNING  152  iteration.
#
#
# RUNNING  153  iteration.
#
#
# RUNNING  154  iteration.
#
#
# RUNNING  155  iteration.
#
#
# RUNNING  156  iteration.
#
#
# RUNNING  157  iteration.
#
#
# RUNNING  158  iteration.
#
#
# RUNNING  159  iteration.
#
#
# RUNNING  160  iteration.
#
#
# RUNNING  161  iteration.
#
#
# RUNNING  162  iteration.
#
#
# RUNNING  163  iteration.
#
#
# RUNNING  164  iteration.
#
#
# RUNNING  165  iteration.
#
#
# RUNNING  166  iteration.
#
#
# RUNNING  167  iteration.
#
#
# RUNNING  168  iteration.
#
#
# RUNNING  169  iteration.
#
#
# RUNNING  170  iteration.
#
#
# RUNNING  171  iteration.
#
#
# RUNNING  172  iteration.
#
#
# RUNNING  173  iteration.
#
#
# RUNNING  174  iteration.
#
#
# RUNNING  175  iteration.
#
#
# RUNNING  176  iteration.
#
#
# RUNNING  177  iteration.
#
#
# RUNNING  178  iteration.
#
#
# RUNNING  179  iteration.
#
#
# RUNNING  180  iteration.
#
#
# RUNNING  181  iteration.
#
#
# RUNNING  182  iteration.
#
#
# RUNNING  183  iteration.
#
#
# RUNNING  184  iteration.
#
#
# RUNNING  185  iteration.
#
#
# RUNNING  186  iteration.
#
#
# RUNNING  187  iteration.
#
#
# RUNNING  188  iteration.
#
#
# RUNNING  189  iteration.
#
#
# RUNNING  190  iteration.
#
#
# RUNNING  191  iteration.
#
#
# RUNNING  192  iteration.
#
#
# RUNNING  193  iteration.
#
#
# RUNNING  194  iteration.
#
#
# RUNNING  195  iteration.
#
#
# RUNNING  196  iteration.
#
#
# RUNNING  197  iteration.
#
#
# RUNNING  198  iteration.
#
#
# RUNNING  199  iteration.
#
#
# RUNNING  200  iteration.
#
#
# RUNNING  201  iteration.
#
#
# RUNNING  202  iteration.
#
#
# RUNNING  203  iteration.
#
#
# RUNNING  204  iteration.
#
#
# RUNNING  205  iteration.
#
#
# RUNNING  206  iteration.
#
#
# RUNNING  207  iteration.
#
#
# RUNNING  208  iteration.
#
#
# RUNNING  209  iteration.
#
#
# RUNNING  210  iteration.
#
#
# RUNNING  211  iteration.
#
#
# RUNNING  212  iteration.
#
#
# RUNNING  213  iteration.
#
#
# RUNNING  214  iteration.
#
#
# RUNNING  215  iteration.
#
#
# RUNNING  216  iteration.
#
#
# RUNNING  217  iteration.
#
#
# RUNNING  218  iteration.
#
#
# RUNNING  219  iteration.
#
#
# RUNNING  220  iteration.
#
#
# RUNNING  221  iteration.
#
#
# RUNNING  222  iteration.
#
#
# RUNNING  223  iteration.
#
#
# RUNNING  224  iteration.
#
#
# RUNNING  225  iteration.
#
#
# RUNNING  226  iteration.
#
#
# RUNNING  227  iteration.
#
#
# RUNNING  228  iteration.
#
#
# RUNNING  229  iteration.
#
#
# RUNNING  230  iteration.
#
#
# RUNNING  231  iteration.
#
#
# RUNNING  232  iteration.
#
#
# RUNNING  233  iteration.
#
#
# RUNNING  234  iteration.
#
#
# RUNNING  235  iteration.
#
#
# RUNNING  236  iteration.
#
#
# RUNNING  237  iteration.
#
#
# RUNNING  238  iteration.
#
#
# RUNNING  239  iteration.
#
#
# RUNNING  240  iteration.
#
#
# RUNNING  241  iteration.
#
#
# RUNNING  242  iteration.
#
#
# RUNNING  243  iteration.
#
#
# RUNNING  244  iteration.
#
#
# RUNNING  245  iteration.
#
#
# RUNNING  246  iteration.
#
#
# RUNNING  247  iteration.
#
#
# RUNNING  248  iteration.
#
#
# RUNNING  249  iteration.
#
#
# RUNNING  250  iteration.
#
#
# RUNNING  251  iteration.
#
#
# RUNNING  252  iteration.
#
#
# RUNNING  253  iteration.
#
#
# RUNNING  254  iteration.
#
#
# RUNNING  255  iteration.
#
#
# RUNNING  256  iteration.
#
#
# RUNNING  257  iteration.
#
#
# RUNNING  258  iteration.
#
#
# RUNNING  259  iteration.
#
#
# RUNNING  260  iteration.
#
#
# RUNNING  261  iteration.
#
#
# RUNNING  262  iteration.
#
#
# RUNNING  263  iteration.
#
#
# RUNNING  264  iteration.
#
#
# RUNNING  265  iteration.
#
#
# RUNNING  266  iteration.
#
#
# RUNNING  267  iteration.
#
#
# RUNNING  268  iteration.
#
#
# RUNNING  269  iteration.
#
#
# RUNNING  270  iteration.
#
#
# RUNNING  271  iteration.
#
#
# RUNNING  272  iteration.
#
#
# RUNNING  273  iteration.
#
#
# RUNNING  274  iteration.
#
#
# RUNNING  275  iteration.
#
#
# RUNNING  276  iteration.
#
#
# RUNNING  277  iteration.
#
#
# RUNNING  278  iteration.
#
#
# RUNNING  279  iteration.
#
#
# RUNNING  280  iteration.
#
#
# RUNNING  281  iteration.
#
#
# RUNNING  282  iteration.
#
#
# RUNNING  283  iteration.
#
#
# RUNNING  284  iteration.
#
#
# RUNNING  285  iteration.
#
#
# RUNNING  286  iteration.
#
#
# RUNNING  287  iteration.
#
#
# RUNNING  288  iteration.
#
#
# RUNNING  289  iteration.
#
#
# RUNNING  290  iteration.
#
#
# RUNNING  291  iteration.
#
#
# RUNNING  292  iteration.
#
#
# RUNNING  293  iteration.
#
#
# RUNNING  294  iteration.
#
#
# RUNNING  295  iteration.
#
#
# RUNNING  296  iteration.
#
#
# RUNNING  297  iteration.
#
#
# RUNNING  298  iteration.
#
#
# RUNNING  299  iteration.
#
#
# RUNNING  300  iteration.
#
#
# RUNNING  301  iteration.
#
#
# RUNNING  302  iteration.
#
#
# RUNNING  303  iteration.
#
#
# RUNNING  304  iteration.
#
#
# RUNNING  305  iteration.
#
#
# RUNNING  306  iteration.
#
#
# RUNNING  307  iteration.
#
#
# RUNNING  308  iteration.
# RUNNING  309  iteration.
#
#
# RUNNING  310  iteration.
#
#
# RUNNING  311  iteration.
#
#
# RUNNING  312  iteration.
#
#
# RUNNING  313  iteration.
#
#
# RUNNING  314  iteration.
#
#
# RUNNING  315  iteration.
#
#
# RUNNING  316  iteration.
#
#
# RUNNING  317  iteration.
#
#
# RUNNING  318  iteration.
#
#
# RUNNING  319  iteration.
#
#
# RUNNING  320  iteration.
#
#
# RUNNING  321  iteration.
#
#
# RUNNING  322  iteration.
#
#
# RUNNING  323  iteration.
#
#
# RUNNING  324  iteration.
#
#
# RUNNING  325  iteration.
#
#
# RUNNING  326  iteration.
#
#
# RUNNING  327  iteration.
#
#
# RUNNING  328  iteration.
#
#
# RUNNING  329  iteration.
#
#
# RUNNING  330  iteration.
#
#
# RUNNING  331  iteration.
#
#
# RUNNING  332  iteration.
#
#
# RUNNING  333  iteration.
#
#
# RUNNING  334  iteration.
#
#
# RUNNING  335  iteration.
#
#
# RUNNING  336  iteration.
#
#
# RUNNING  337  iteration.
#
#
# RUNNING  338  iteration.
#
#
# RUNNING  339  iteration.
#
#
# RUNNING  340  iteration.
#
#
# RUNNING  341  iteration.
#
#
# RUNNING  342  iteration.
#
#
# RUNNING  343  iteration.
#
#
# RUNNING  344  iteration.
#
#
# RUNNING  345  iteration.
#
#
# RUNNING  346  iteration.
#
#
# RUNNING  347  iteration.
#
#
# RUNNING  348  iteration.
#
#
# RUNNING  349  iteration.
#
#
# RUNNING  350  iteration.
#
#
# RUNNING  351  iteration.
#
#
# RUNNING  352  iteration.
#
#
# RUNNING  353  iteration.
#
#
# RUNNING  354  iteration.
#
#
# RUNNING  355  iteration.
#
#
# RUNNING  356  iteration.
#
#
# RUNNING  357  iteration.
#
#
# RUNNING  358  iteration.
#
#
# RUNNING  359  iteration.
#
#
# RUNNING  360  iteration.
#
#
# RUNNING  361  iteration.
#
#
# RUNNING  362  iteration.
#
#
# RUNNING  363  iteration.
#
#
# RUNNING  364  iteration.
#
#
# RUNNING  365  iteration.
#
#
# RUNNING  366  iteration.
#
#
# RUNNING  367  iteration.
#
#
# RUNNING  368  iteration.
#
#
# RUNNING  369  iteration.
#
#
# RUNNING  370  iteration.
#
#
# RUNNING  371  iteration.
#
#
# RUNNING  372  iteration.
#
#
# RUNNING  373  iteration.
#
#
# RUNNING  374  iteration.
#
#
# RUNNING  375  iteration.
#
#
# RUNNING  376  iteration.
#
#
# RUNNING  377  iteration.
#
#
# RUNNING  378  iteration.
#
#
# RUNNING  379  iteration.
#
#
# RUNNING  380  iteration.
#
#
# RUNNING  381  iteration.
#
#
# RUNNING  382  iteration.
#
#
# RUNNING  383  iteration.
#
#
# RUNNING  384  iteration.
#
#
# RUNNING  385  iteration.
#
#
# RUNNING  386  iteration.
#
#
# RUNNING  387  iteration.
#
#
# RUNNING  388  iteration.
#
#
# RUNNING  389  iteration.
#
#
# RUNNING  390  iteration.
#
#
# RUNNING  391  iteration.
#
#
# RUNNING  392  iteration.
#
#
# RUNNING  393  iteration.
#
#
# RUNNING  394  iteration.
#
#
# RUNNING  395  iteration.
#
#
# RUNNING  396  iteration.
#
#
# RUNNING  397  iteration.
#
#
# RUNNING  398  iteration.
#
#
# RUNNING  399  iteration.
#
#
# RUNNING  400  iteration.
#
#
# RUNNING  401  iteration.
#
#
# RUNNING  402  iteration.
#
#
# RUNNING  403  iteration.
#
#
# RUNNING  404  iteration.
#
#
# RUNNING  405  iteration.
#
#
# RUNNING  406  iteration.
#
#
# RUNNING  407  iteration.
#
#
# RUNNING  408  iteration.
#
#
# RUNNING  409  iteration.
#
#
# RUNNING  410  iteration.
#
#
# RUNNING  411  iteration.
#
#
# RUNNING  412  iteration.
#
#
# RUNNING  413  iteration.
#
#
# RUNNING  414  iteration.
#
#
# RUNNING  415  iteration.
#
#
# RUNNING  416  iteration.
#
#
# RUNNING  417  iteration.
#
#
# RUNNING  418  iteration.
#
#
# RUNNING  419  iteration.
#
#
# RUNNING  420  iteration.
#
#
# RUNNING  421  iteration.
#
#
# RUNNING  422  iteration.
#
#
# RUNNING  423  iteration.
#
#
# RUNNING  424  iteration.
#
#
# RUNNING  425  iteration.
#
#
# RUNNING  426  iteration.
#
#
# RUNNING  427  iteration.
#
#
# RUNNING  428  iteration.
#
#
# RUNNING  429  iteration.
#
#
# RUNNING  430  iteration.
#
#
# RUNNING  431  iteration.
#
#
# RUNNING  432  iteration.
#
#
# RUNNING  433  iteration.
#
#
# RUNNING  434  iteration.
#
#
# RUNNING  435  iteration.
#
#
# RUNNING  436  iteration.
#
#
# RUNNING  437  iteration.
#
#
# RUNNING  438  iteration.
#
#
# RUNNING  439  iteration.
#
#
# RUNNING  440  iteration.
#
#
# RUNNING  441  iteration.
#
#
# RUNNING  442  iteration.
#
#
# RUNNING  443  iteration.
#
#
# RUNNING  444  iteration.
#
#
# RUNNING  445  iteration.
#
#
# RUNNING  446  iteration.
#
#
# RUNNING  447  iteration.
#
#
# RUNNING  448  iteration.
#
#
# RUNNING  449  iteration.
#
#
# RUNNING  450  iteration.
#
#
# RUNNING  451  iteration.
#
#
# RUNNING  452  iteration.
#
#
# RUNNING  453  iteration.
#
#
# RUNNING  454  iteration.
#
#
# RUNNING  455  iteration.
#
#
# RUNNING  456  iteration.
#
#
# RUNNING  457  iteration.
#
#
# RUNNING  458  iteration.
#
#
# RUNNING  459  iteration.
#
#
# RUNNING  460  iteration.
#
#
# RUNNING  461  iteration.
#
#
# RUNNING  462  iteration.
#
#
# RUNNING  463  iteration.
#
#
# RUNNING  464  iteration.
#
#
# RUNNING  465  iteration.
#
#
# RUNNING  466  iteration.
#
#
# RUNNING  467  iteration.
#
#
# RUNNING  468  iteration.
#
#
# RUNNING  469  iteration.
#
#
# RUNNING  470  iteration.
#
#
# RUNNING  471  iteration.
#
#
# RUNNING  472  iteration.
#
#
# RUNNING  473  iteration.
#
#
# RUNNING  474  iteration.
#
#
# RUNNING  475  iteration.
#
#
# RUNNING  476  iteration.
#
#
# RUNNING  477  iteration.
#
#
# RUNNING  478  iteration.
#
#
# RUNNING  479  iteration.
#
#
# RUNNING  480  iteration.
#
#
# RUNNING  481  iteration.
#
#
# RUNNING  482  iteration.
#
#
# RUNNING  483  iteration.
#
#
# RUNNING  484  iteration.
#
#
# RUNNING  485  iteration.
#
#
# RUNNING  486  iteration.
#
#
# RUNNING  487  iteration.
#
#
# RUNNING  488  iteration.
#
#
# RUNNING  489  iteration.
#
#
# RUNNING  490  iteration.
#
#
# RUNNING  491  iteration.
#
#
# RUNNING  492  iteration.
#
#
# RUNNING  493  iteration.
#
#
# RUNNING  494  iteration.
#
#
# RUNNING  495  iteration.
#
#
# RUNNING  496  iteration.
#
#
# RUNNING  497  iteration.
#
#
# RUNNING  498  iteration.
#
#
# RUNNING  499  iteration.
#
#
# RUNNING  500  iteration.
#
#
# RUNNING  501  iteration.
#
#
# RUNNING  502  iteration.
#
#
# RUNNING  503  iteration.
#
#
# RUNNING  504  iteration.
#
#
# RUNNING  505  iteration.
#
#
# RUNNING  506  iteration.
#
#
# RUNNING  507  iteration.
#
#
# RUNNING  508  iteration.
#
#
# RUNNING  509  iteration.
#
#
# RUNNING  510  iteration.
#
#
# RUNNING  511  iteration.
#
#
# RUNNING  512  iteration.
#
#
# RUNNING  513  iteration.
#
#
# RUNNING  514  iteration.
#
#
# RUNNING  515  iteration.
#
#
# RUNNING  516  iteration.
#
#
# RUNNING  517  iteration.
#
#
# RUNNING  518  iteration.
#
#
# RUNNING  519  iteration.
#
#
# RUNNING  520  iteration.
#
#
# RUNNING  521  iteration.
#
#
# RUNNING  522  iteration.
#
#
# RUNNING  523  iteration.
#
#
# RUNNING  524  iteration.
#
#
# RUNNING  525  iteration.
#
#
# RUNNING  526  iteration.
#
#
# RUNNING  527  iteration.
#
#
# RUNNING  528  iteration.
#
#
# RUNNING  529  iteration.
#
#
# RUNNING  530  iteration.
#
#
# RUNNING  531  iteration.
#
#
# RUNNING  532  iteration.
#
#
# RUNNING  533  iteration.
#
#
# RUNNING  534  iteration.
#
#
# RUNNING  535  iteration.
#
#
# RUNNING  536  iteration.
#
#
# RUNNING  537  iteration.
#
#
# RUNNING  538  iteration.
#
#
# RUNNING  539  iteration.
#
#
# RUNNING  540  iteration.
#
#
# RUNNING  541  iteration.
#
#
# RUNNING  542  iteration.
#
#
# RUNNING  543  iteration.
#
#
# RUNNING  544  iteration.
#
#
# RUNNING  545  iteration.
#
#
# RUNNING  546  iteration.
#
#
# RUNNING  547  iteration.
#
#
# RUNNING  548  iteration.
#
#
# RUNNING  549  iteration.
#
#
# RUNNING  550  iteration.
#
#
# RUNNING  551  iteration.
#
#
# RUNNING  552  iteration.
#
#
# RUNNING  553  iteration.
#
#
# RUNNING  554  iteration.
#
#
# RUNNING  555  iteration.
#
#
# RUNNING  556  iteration.
#
#
# RUNNING  557  iteration.
#
#
# RUNNING  558  iteration.
#
#
# RUNNING  559  iteration.
#
#
# RUNNING  560  iteration.
#
#
# RUNNING  561  iteration.
#
#
# RUNNING  562  iteration.
#
#
# RUNNING  563  iteration.
#
#
# RUNNING  564  iteration.
#
#
# RUNNING  565  iteration.
#
#
# RUNNING  566  iteration.
#
#
# RUNNING  567  iteration.
#
#
# RUNNING  568  iteration.
#
#
# RUNNING  569  iteration.
#
#
# RUNNING  570  iteration.
#
#
# RUNNING  571  iteration.
#
#
# RUNNING  572  iteration.
#
#
# RUNNING  573  iteration.
#
#
# RUNNING  574  iteration.
#
#
# RUNNING  575  iteration.
#
#
# RUNNING  576  iteration.
#
#
# RUNNING  577  iteration.
#
#
# RUNNING  578  iteration.
#
#
# RUNNING  579  iteration.
#
#
# RUNNING  580  iteration.
#
#
# RUNNING  581  iteration.
#
#
# RUNNING  582  iteration.
#
#
# RUNNING  583  iteration.
#
#
# RUNNING  584  iteration.
#
#
# RUNNING  585  iteration.
#
#
# RUNNING  586  iteration.
#
#
# RUNNING  587  iteration.
#
#
# RUNNING  588  iteration.
#
#
# RUNNING  589  iteration.
#
#
# RUNNING  590  iteration.
#
#
# RUNNING  591  iteration.
#
#
# RUNNING  592  iteration.
#
#
# RUNNING  593  iteration.
#
#
# RUNNING  594  iteration.
#
#
# RUNNING  595  iteration.
#
#
# RUNNING  596  iteration.
#
#
# RUNNING  597  iteration.
#
#
# RUNNING  598  iteration.
#
#
# RUNNING  599  iteration.
#
#
# RUNNING  600  iteration.
#
#
# RUNNING  601  iteration.
#
#
# RUNNING  602  iteration.
#
#
# RUNNING  603  iteration.
#
#
# RUNNING  604  iteration.
#
#
# RUNNING  605  iteration.
#
#
# RUNNING  606  iteration.
#
#
# RUNNING  607  iteration.
#
#
# RUNNING  608  iteration.
#
#
# RUNNING  609  iteration.
#
#
# RUNNING  610  iteration.
#
#
# RUNNING  611  iteration.
#
#
# RUNNING  612  iteration.
# RUNNING  613  iteration.
#
#
# RUNNING  614  iteration.
#
#
# RUNNING  615  iteration.
#
#
# RUNNING  616  iteration.
#
#
# RUNNING  617  iteration.
#
#
# RUNNING  618  iteration.
#
#
# RUNNING  619  iteration.
#
#
# RUNNING  620  iteration.
#
#
# RUNNING  621  iteration.
#
#
# RUNNING  622  iteration.
#
#
# RUNNING  623  iteration.
#
#
# RUNNING  624  iteration.
#
#
# RUNNING  625  iteration.
#
#
# RUNNING  626  iteration.
#
#
# RUNNING  627  iteration.
#
#
# RUNNING  628  iteration.
#
#
# RUNNING  629  iteration.
#
#
# RUNNING  630  iteration.
#
#
# RUNNING  631  iteration.
#
#
# RUNNING  632  iteration.
#
#
# RUNNING  633  iteration.
#
#
# RUNNING  634  iteration.
#
#
# RUNNING  635  iteration.
#
#
# RUNNING  636  iteration.
#
#
# RUNNING  637  iteration.
#
#
# RUNNING  638  iteration.
#
#
# RUNNING  639  iteration.
#
#
# RUNNING  640  iteration.
#
#
# RUNNING  641  iteration.
#
#
# RUNNING  642  iteration.
#
#
# RUNNING  643  iteration.
#
#
# RUNNING  644  iteration.
#
#
# RUNNING  645  iteration.
#
#
# RUNNING  646  iteration.
#
#
# RUNNING  647  iteration.
#
#
# RUNNING  648  iteration.
#
#
# RUNNING  649  iteration.
#
#
# RUNNING  650  iteration.
#
#
# RUNNING  651  iteration.
#
#
# RUNNING  652  iteration.
#
#
# RUNNING  653  iteration.
#
#
# RUNNING  654  iteration.
#
#
# RUNNING  655  iteration.
#
#
# RUNNING  656  iteration.
#
#
# RUNNING  657  iteration.
#
#
# RUNNING  658  iteration.
#
#
# RUNNING  659  iteration.
#
#
# RUNNING  660  iteration.
#
#
# RUNNING  661  iteration.
#
#
# RUNNING  662  iteration.
#
#
# RUNNING  663  iteration.
#
#
# RUNNING  664  iteration.
#
#
# RUNNING  665  iteration.
#
#
# RUNNING  666  iteration.
#
#
# RUNNING  667  iteration.
#
#
# RUNNING  668  iteration.
#
#
# RUNNING  669  iteration.
#
#
# RUNNING  670  iteration.
#
#
# RUNNING  671  iteration.
#
#
# RUNNING  672  iteration.
#
#
# RUNNING  673  iteration.
#
#
# RUNNING  674  iteration.
#
#
# RUNNING  675  iteration.
#
#
# RUNNING  676  iteration.
#
#
# RUNNING  677  iteration.
#
#
# RUNNING  678  iteration.
#
#
# RUNNING  679  iteration.
#
#
# RUNNING  680  iteration.
#
#
# RUNNING  681  iteration.
#
#
# RUNNING  682  iteration.
#
#
# RUNNING  683  iteration.
#
#
# RUNNING  684  iteration.
#
#
# RUNNING  685  iteration.
#
#
# RUNNING  686  iteration.
#
#
# RUNNING  687  iteration.
#
#
# RUNNING  688  iteration.
#
#
# RUNNING  689  iteration.
#
#
# RUNNING  690  iteration.
#
#
# RUNNING  691  iteration.
#
#
# RUNNING  692  iteration.
#
#
# RUNNING  693  iteration.
#
#
# RUNNING  694  iteration.
#
#
# RUNNING  695  iteration.
#
#
# RUNNING  696  iteration.
#
#
# RUNNING  697  iteration.
#
#
# RUNNING  698  iteration.
#
#
# RUNNING  699  iteration.
#
#
# RUNNING  700  iteration.
#
#
# RUNNING  701  iteration.
#
#
# RUNNING  702  iteration.
#
#
# RUNNING  703  iteration.
#
#
# RUNNING  704  iteration.
#
#
# RUNNING  705  iteration.
#
#
# RUNNING  706  iteration.
#
#
# RUNNING  707  iteration.
#
#
# RUNNING  708  iteration.
#
#
# RUNNING  709  iteration.
#
#
# RUNNING  710  iteration.
#
#
# RUNNING  711  iteration.
#
#
# RUNNING  712  iteration.
#
#
# RUNNING  713  iteration.
#
#
# RUNNING  714  iteration.
#
#
# RUNNING  715  iteration.
#
#
# RUNNING  716  iteration.
#
#
# RUNNING  717  iteration.
#
#
# RUNNING  718  iteration.
#
#
# RUNNING  719  iteration.
#
#
# RUNNING  720  iteration.
#
#
# RUNNING  721  iteration.
#
#
# RUNNING  722  iteration.
#
#
# RUNNING  723  iteration.
#
#
# RUNNING  724  iteration.
#
#
# RUNNING  725  iteration.
#
#
# RUNNING  726  iteration.
#
#
# RUNNING  727  iteration.
#
#
# RUNNING  728  iteration.
#
#
# RUNNING  729  iteration.
#
#
# RUNNING  730  iteration.
#
#
# RUNNING  731  iteration.
#
#
# RUNNING  732  iteration.
#
#
# RUNNING  733  iteration.
#
#
# RUNNING  734  iteration.
#
#
# RUNNING  735  iteration.
#
#
# RUNNING  736  iteration.
#
#
# RUNNING  737  iteration.
#
#
# RUNNING  738  iteration.
#
#
# RUNNING  739  iteration.
#
#
# RUNNING  740  iteration.
#
#
# RUNNING  741  iteration.
#
#
# RUNNING  742  iteration.
#
#
# RUNNING  743  iteration.
#
#
# RUNNING  744  iteration.
#
#
# RUNNING  745  iteration.
#
#
# RUNNING  746  iteration.
#
#
# RUNNING  747  iteration.
#
#
# RUNNING  748  iteration.
#
#
# RUNNING  749  iteration.
#
#
# RUNNING  750  iteration.
#
#
# RUNNING  751  iteration.
#
#
# RUNNING  752  iteration.
#
#
# RUNNING  753  iteration.
#
#
# RUNNING  754  iteration.
#
#
# RUNNING  755  iteration.
#
#
# RUNNING  756  iteration.
#
#
# RUNNING  757  iteration.
#
#
# RUNNING  758  iteration.
#
#
# RUNNING  759  iteration.
#
#
# RUNNING  760  iteration.
#
#
# RUNNING  761  iteration.
#
#
# RUNNING  762  iteration.
#
#
# RUNNING  763  iteration.
#
#
# RUNNING  764  iteration.
#
#
# RUNNING  765  iteration.
#
#
# RUNNING  766  iteration.
#
#
# RUNNING  767  iteration.
#
#
# RUNNING  768  iteration.
#
#
# RUNNING  769  iteration.
#
#
# RUNNING  770  iteration.
#
#
# RUNNING  771  iteration.
#
#
# RUNNING  772  iteration.
#
#
# RUNNING  773  iteration.
#
#
# RUNNING  774  iteration.
#
#
# RUNNING  775  iteration.
#
#
# RUNNING  776  iteration.
#
#
# RUNNING  777  iteration.
#
#
# RUNNING  778  iteration.
#
#
# RUNNING  779  iteration.
#
#
# RUNNING  780  iteration.
#
#
# RUNNING  781  iteration.
#
#
# RUNNING  782  iteration.
#
#
# RUNNING  783  iteration.
#
#
# RUNNING  784  iteration.
#
#
# RUNNING  785  iteration.
#
#
# RUNNING  786  iteration.
#
#
# RUNNING  787  iteration.
#
#
# RUNNING  788  iteration.
#
#
# RUNNING  789  iteration.
#
#
# RUNNING  790  iteration.
#
#
# RUNNING  791  iteration.
#
#
# RUNNING  792  iteration.
#
#
# RUNNING  793  iteration.
#
#
# RUNNING  794  iteration.
#
#
# RUNNING  795  iteration.
#
#
# RUNNING  796  iteration.
#
#
# RUNNING  797  iteration.
#
#
# RUNNING  798  iteration.
#
#
# RUNNING  799  iteration.
#
#
# RUNNING  800  iteration.
#
#
# RUNNING  801  iteration.
#
#
# RUNNING  802  iteration.
#
#
# RUNNING  803  iteration.
#
#
# RUNNING  804  iteration.
#
#
# RUNNING  805  iteration.
#
#
# RUNNING  806  iteration.
#
#
# RUNNING  807  iteration.
#
#
# RUNNING  808  iteration.
#
#
# RUNNING  809  iteration.
#
#
# RUNNING  810  iteration.
#
#
# RUNNING  811  iteration.
#
#
# RUNNING  812  iteration.
#
#
# RUNNING  813  iteration.
#
#
# RUNNING  814  iteration.
#
#
# RUNNING  815  iteration.
#
#
# RUNNING  816  iteration.
#
#
# RUNNING  817  iteration.
#
#
# RUNNING  818  iteration.
#
#
# RUNNING  819  iteration.
#
#
# RUNNING  820  iteration.
#
#
# RUNNING  821  iteration.
#
#
# RUNNING  822  iteration.
#
#
# RUNNING  823  iteration.
#
#
# RUNNING  824  iteration.
#
#
# RUNNING  825  iteration.
#
#
# RUNNING  826  iteration.
#
#
# RUNNING  827  iteration.
#
#
# RUNNING  828  iteration.
#
#
# RUNNING  829  iteration.
#
#
# RUNNING  830  iteration.
#
#
# RUNNING  831  iteration.
#
#
# RUNNING  832  iteration.
#
#
# RUNNING  833  iteration.
#
#
# RUNNING  834  iteration.
#
#
# RUNNING  835  iteration.
#
#
# RUNNING  836  iteration.
#
#
# RUNNING  837  iteration.
#
#
# RUNNING  838  iteration.
#
#
# RUNNING  839  iteration.
#
#
# RUNNING  840  iteration.
#
#
# RUNNING  841  iteration.
#
#
# RUNNING  842  iteration.
#
#
# RUNNING  843  iteration.
#
#
# RUNNING  844  iteration.
#
#
# RUNNING  845  iteration.
#
#
# RUNNING  846  iteration.
#
#
# RUNNING  847  iteration.
#
#
# RUNNING  848  iteration.
#
#
# RUNNING  849  iteration.
#
#
# RUNNING  850  iteration.
#
#
# RUNNING  851  iteration.
#
#
# RUNNING  852  iteration.
#
#
# RUNNING  853  iteration.
#
#
# RUNNING  854  iteration.
#
#
# RUNNING  855  iteration.
#
#
# RUNNING  856  iteration.
#
#
# RUNNING  857  iteration.
#
#
# RUNNING  858  iteration.
#
#
# RUNNING  859  iteration.
#
#
# RUNNING  860  iteration.
#
#
# RUNNING  861  iteration.
#
#
# RUNNING  862  iteration.
#
#
# RUNNING  863  iteration.
#
#
# RUNNING  864  iteration.
#
#
# RUNNING  865  iteration.
#
#
# RUNNING  866  iteration.
#
#
# RUNNING  867  iteration.
#
#
# RUNNING  868  iteration.
#
#
# RUNNING  869  iteration.
#
#
# RUNNING  870  iteration.
#
#
# RUNNING  871  iteration.
#
#
# RUNNING  872  iteration.
#
#
# RUNNING  873  iteration.
#
#
# RUNNING  874  iteration.
#
#
# RUNNING  875  iteration.
#
#
# RUNNING  876  iteration.
#
#
# RUNNING  877  iteration.
#
#
# RUNNING  878  iteration.
#
#
# RUNNING  879  iteration.
#
#
# RUNNING  880  iteration.
#
#
# RUNNING  881  iteration.
#
#
# RUNNING  882  iteration.
#
#
# RUNNING  883  iteration.
#
#
# RUNNING  884  iteration.
#
#
# RUNNING  885  iteration.
#
#
# RUNNING  886  iteration.
#
#
# RUNNING  887  iteration.
#
#
# RUNNING  888  iteration.
#
#
# RUNNING  889  iteration.
#
#
# RUNNING  890  iteration.
#
#
# RUNNING  891  iteration.
#
#
# RUNNING  892  iteration.
#
#
# RUNNING  893  iteration.
#
#
# RUNNING  894  iteration.
#
#
# RUNNING  895  iteration.
#
#
# RUNNING  896  iteration.
#
#
# RUNNING  897  iteration.
#
#
# RUNNING  898  iteration.
#
#
# RUNNING  899  iteration.
#
#
# RUNNING  900  iteration.
#
#
# RUNNING  901  iteration.
#
#
# RUNNING  902  iteration.
#
#
# RUNNING  903  iteration.
#
#
# RUNNING  904  iteration.
#
#
# RUNNING  905  iteration.
#
#
# RUNNING  906  iteration.
#
#
# RUNNING  907  iteration.
#
#
# RUNNING  908  iteration.
#
#
# RUNNING  909  iteration.
#
#
# RUNNING  910  iteration.
#
#
# RUNNING  911  iteration.
#
#
# RUNNING  912  iteration.
#
#
# RUNNING  913  iteration.
#
#
# RUNNING  914  iteration.
#
#
# RUNNING  915  iteration.
#
#
# RUNNING  916  iteration.
# RUNNING  917  iteration.
#
#
# RUNNING  918  iteration.
#
#
# RUNNING  919  iteration.
#
#
# RUNNING  920  iteration.
#
#
# RUNNING  921  iteration.
#
#
# RUNNING  922  iteration.
#
#
# RUNNING  923  iteration.
#
#
# RUNNING  924  iteration.
#
#
# RUNNING  925  iteration.
#
#
# RUNNING  926  iteration.
#
#
# RUNNING  927  iteration.
#
#
# RUNNING  928  iteration.
#
#
# RUNNING  929  iteration.
#
#
# RUNNING  930  iteration.
#
#
# RUNNING  931  iteration.
#
#
# RUNNING  932  iteration.
#
#
# RUNNING  933  iteration.
#
#
# RUNNING  934  iteration.
#
#
# RUNNING  935  iteration.
#
#
# RUNNING  936  iteration.
#
#
# RUNNING  937  iteration.
#
#
# RUNNING  938  iteration.
#
#
# RUNNING  939  iteration.
#
#
# RUNNING  940  iteration.
#
#
# RUNNING  941  iteration.
#
#
# RUNNING  942  iteration.
#
#
# RUNNING  943  iteration.
#
#
# RUNNING  944  iteration.
#
#
# RUNNING  945  iteration.
#
#
# RUNNING  946  iteration.
#
#
# RUNNING  947  iteration.
#
#
# RUNNING  948  iteration.
#
#
# RUNNING  949  iteration.
#
#
# RUNNING  950  iteration.
#
#
# RUNNING  951  iteration.
#
#
# RUNNING  952  iteration.
#
#
# RUNNING  953  iteration.
#
#
# RUNNING  954  iteration.
#
#
# RUNNING  955  iteration.
#
#
# RUNNING  956  iteration.
#
#
# RUNNING  957  iteration.
#
#
# RUNNING  958  iteration.
#
#
# RUNNING  959  iteration.
#
#
# RUNNING  960  iteration.
#
#
# RUNNING  961  iteration.
#
#
# RUNNING  962  iteration.
#
#
# RUNNING  963  iteration.
#
#
# RUNNING  964  iteration.
#
#
# RUNNING  965  iteration.
#
#
# RUNNING  966  iteration.
#
#
# RUNNING  967  iteration.
#
#
# RUNNING  968  iteration.
#
#
# RUNNING  969  iteration.
#
#
# RUNNING  970  iteration.
#
#
# RUNNING  971  iteration.
#
#
# RUNNING  972  iteration.
#
#
# RUNNING  973  iteration.
#
#
# RUNNING  974  iteration.
#
#
# RUNNING  975  iteration.
#
#
# RUNNING  976  iteration.
#
#
# RUNNING  977  iteration.
#
#
# RUNNING  978  iteration.
#
#
# RUNNING  979  iteration.
#
#
# RUNNING  980  iteration.
#
#
# RUNNING  981  iteration.
#
#
# RUNNING  982  iteration.
#
#
# RUNNING  983  iteration.
#
#
# RUNNING  984  iteration.
#
#
# RUNNING  985  iteration.
#
#
# RUNNING  986  iteration.
#
#
# RUNNING  987  iteration.
#
#
# RUNNING  988  iteration.
#
#
# RUNNING  989  iteration.
#
#
# RUNNING  990  iteration.
#
#
# RUNNING  991  iteration.
#
#
# RUNNING  992  iteration.
#
#
# RUNNING  993  iteration.
#
#
# RUNNING  994  iteration.
#
#
# RUNNING  995  iteration.
#
#
# RUNNING  996  iteration.
#
#
# RUNNING  997  iteration.
#
#
# RUNNING  998  iteration.
#
#
# RUNNING  999  iteration.
#
#
# RUNNING  1000  iteration.
#
#
# RUNNING  1001  iteration.
#
#
# RUNNING  1002  iteration.
#
#
# RUNNING  1003  iteration.
#
#
# RUNNING  1004  iteration.
#
#
# RUNNING  1005  iteration.
#
#
# RUNNING  1006  iteration.
#
#
# RUNNING  1007  iteration.
#
#
# RUNNING  1008  iteration.
#
#
# RUNNING  1009  iteration.
#
#
# RUNNING  1010  iteration.
#
#
# RUNNING  1011  iteration.
#
#
# RUNNING  1012  iteration.
#
#
# RUNNING  1013  iteration.
#
#
# RUNNING  1014  iteration.
#
#
# RUNNING  1015  iteration.
#
#
# RUNNING  1016  iteration.
#
#
# RUNNING  1017  iteration.
#
#
# RUNNING  1018  iteration.
#
#
# RUNNING  1019  iteration.
#
#
# RUNNING  1020  iteration.
#
#
# RUNNING  1021  iteration.
#
#
# RUNNING  1022  iteration.
#
#
# RUNNING  1023  iteration.
#
#
# RUNNING  1024  iteration.
#
#
# RUNNING  1025  iteration.
#
#
# RUNNING  1026  iteration.
#
#
# RUNNING  1027  iteration.
#
#
# RUNNING  1028  iteration.
#
#
# RUNNING  1029  iteration.
#
#
# RUNNING  1030  iteration.
#
#
# RUNNING  1031  iteration.
#
#
# RUNNING  1032  iteration.
#
#
# RUNNING  1033  iteration.
#
#
# RUNNING  1034  iteration.
#
#
# RUNNING  1035  iteration.
#
#
# RUNNING  1036  iteration.
#
#
# RUNNING  1037  iteration.
#
#
# RUNNING  1038  iteration.
#
#
# RUNNING  1039  iteration.
#
#
# RUNNING  1040  iteration.
#
#
# RUNNING  1041  iteration.
#
#
# RUNNING  1042  iteration.
#
#
# RUNNING  1043  iteration.
#
#
# RUNNING  1044  iteration.
#
#
# RUNNING  1045  iteration.
#
#
# RUNNING  1046  iteration.
#
#
# RUNNING  1047  iteration.
#
#
# RUNNING  1048  iteration.
#
#
# RUNNING  1049  iteration.
#
#
# RUNNING  1050  iteration.
#
#
# RUNNING  1051  iteration.
#
#
# RUNNING  1052  iteration.
#
#
# RUNNING  1053  iteration.
#
#
# RUNNING  1054  iteration.
#
#
# RUNNING  1055  iteration.
#
#
# RUNNING  1056  iteration.
#
#
# RUNNING  1057  iteration.
#
#
# RUNNING  1058  iteration.
#
#
# RUNNING  1059  iteration.
#
#
# RUNNING  1060  iteration.
#
#
# RUNNING  1061  iteration.
#
#
# RUNNING  1062  iteration.
#
#
# RUNNING  1063  iteration.
#
#
# RUNNING  1064  iteration.
#
#
# RUNNING  1065  iteration.
#
#
# RUNNING  1066  iteration.
#
#
# RUNNING  1067  iteration.
#
#
# RUNNING  1068  iteration.
#
#
# RUNNING  1069  iteration.
#
#
# RUNNING  1070  iteration.
#
#
# RUNNING  1071  iteration.
#
#
# RUNNING  1072  iteration.
#
#
# RUNNING  1073  iteration.
#
#
# RUNNING  1074  iteration.
#
#
# RUNNING  1075  iteration.
#
#
# RUNNING  1076  iteration.
#
#
# RUNNING  1077  iteration.
#
#
# RUNNING  1078  iteration.
#
#
# RUNNING  1079  iteration.
#
#
# RUNNING  1080  iteration.
#
#
# RUNNING  1081  iteration.
#
#
# RUNNING  1082  iteration.
#
#
# RUNNING  1083  iteration.
#
#
# RUNNING  1084  iteration.
#
#
# RUNNING  1085  iteration.
#
#
# RUNNING  1086  iteration.
#
#
# RUNNING  1087  iteration.
#
#
# RUNNING  1088  iteration.
#
#
# RUNNING  1089  iteration.
#
#
# RUNNING  1090  iteration.
#
#
# RUNNING  1091  iteration.
#
#
# RUNNING  1092  iteration.
#
#
# RUNNING  1093  iteration.
#
#
# RUNNING  1094  iteration.
#
#
# RUNNING  1095  iteration.
#
#
# RUNNING  1096  iteration.
#
#
# RUNNING  1097  iteration.
#
#
# RUNNING  1098  iteration.
#
#
# RUNNING  1099  iteration.
#
#
# RUNNING  1100  iteration.
#
#
# RUNNING  1101  iteration.
#
#
# RUNNING  1102  iteration.
#
#
# RUNNING  1103  iteration.
#
#
# RUNNING  1104  iteration.
#
#
# RUNNING  1105  iteration.
#
#
# RUNNING  1106  iteration.
#
#
# RUNNING  1107  iteration.
#
#
# RUNNING  1108  iteration.
#
#
# RUNNING  1109  iteration.
#
#
# RUNNING  1110  iteration.
#
#
# RUNNING  1111  iteration.
#
#
# RUNNING  1112  iteration.
#
#
# RUNNING  1113  iteration.
#
#
# RUNNING  1114  iteration.
#
#
# RUNNING  1115  iteration.
#
#
# RUNNING  1116  iteration.
#
#
# RUNNING  1117  iteration.
#
#
# RUNNING  1118  iteration.
#
#
# RUNNING  1119  iteration.
#
#
# RUNNING  1120  iteration.
#
#
# RUNNING  1121  iteration.
#
#
# RUNNING  1122  iteration.
#
#
# RUNNING  1123  iteration.
#
#
# RUNNING  1124  iteration.
#
#
# RUNNING  1125  iteration.
#
#
# RUNNING  1126  iteration.
#
#
# RUNNING  1127  iteration.
#
#
# RUNNING  1128  iteration.
#
#
# RUNNING  1129  iteration.
#
#
# RUNNING  1130  iteration.
#
#
# RUNNING  1131  iteration.
#
#
# RUNNING  1132  iteration.
#
#
# RUNNING  1133  iteration.
#
#
# RUNNING  1134  iteration.
#
#
# RUNNING  1135  iteration.
#
#
# RUNNING  1136  iteration.
#
#
# RUNNING  1137  iteration.
#
#
# RUNNING  1138  iteration.
#
#
# RUNNING  1139  iteration.
#
#
# RUNNING  1140  iteration.
#
#
# RUNNING  1141  iteration.
#
#
# RUNNING  1142  iteration.
#
#
# RUNNING  1143  iteration.
#
#
# RUNNING  1144  iteration.
#
#
# RUNNING  1145  iteration.
#
#
# RUNNING  1146  iteration.
#
#
# RUNNING  1147  iteration.
#
#
# RUNNING  1148  iteration.
#
#
# RUNNING  1149  iteration.
#
#
# RUNNING  1150  iteration.
#
#
# RUNNING  1151  iteration.
#
#
# RUNNING  1152  iteration.
#
#
# RUNNING  1153  iteration.
#
#
# RUNNING  1154  iteration.
#
#
# RUNNING  1155  iteration.
#
#
# RUNNING  1156  iteration.
#
#
# RUNNING  1157  iteration.
#
#
# RUNNING  1158  iteration.
#
#
# RUNNING  1159  iteration.
#
#
# RUNNING  1160  iteration.
#
#
# RUNNING  1161  iteration.
#
#
# RUNNING  1162  iteration.
#
#
# RUNNING  1163  iteration.
#
#
# RUNNING  1164  iteration.
#
#
# RUNNING  1165  iteration.
#
#
# RUNNING  1166  iteration.
#
#
# RUNNING  1167  iteration.
#
#
# RUNNING  1168  iteration.
#
#
# RUNNING  1169  iteration.
#
#
# RUNNING  1170  iteration.
#
#
# RUNNING  1171  iteration.
#
#
# RUNNING  1172  iteration.
#
#
# RUNNING  1173  iteration.
#
#
# RUNNING  1174  iteration.
#
#
# RUNNING  1175  iteration.
#
#
# RUNNING  1176  iteration.
#
#
# RUNNING  1177  iteration.
#
#
# RUNNING  1178  iteration.
#
#
# RUNNING  1179  iteration.
#
#
# RUNNING  1180  iteration.
#
#
# RUNNING  1181  iteration.
#
#
# RUNNING  1182  iteration.
#
#
# RUNNING  1183  iteration.
#
#
# RUNNING  1184  iteration.
#
#
# RUNNING  1185  iteration.
#
#
# RUNNING  1186  iteration.
#
#
# RUNNING  1187  iteration.
#
#
# RUNNING  1188  iteration.
#
#
# RUNNING  1189  iteration.
#
#
# RUNNING  1190  iteration.
#
#
# RUNNING  1191  iteration.
#
#
# RUNNING  1192  iteration.
#
#
# RUNNING  1193  iteration.
#
#
# RUNNING  1194  iteration.
#
#
# RUNNING  1195  iteration.
#
#
# RUNNING  1196  iteration.
#
#
# RUNNING  1197  iteration.
#
#
# RUNNING  1198  iteration.
#
#
# RUNNING  1199  iteration.
#
#
# RUNNING  1200  iteration.
#
#
# RUNNING  1201  iteration.
#
#
# RUNNING  1202  iteration.
#
#
# RUNNING  1203  iteration.
#
#
# RUNNING  1204  iteration.
#
#
# RUNNING  1205  iteration.
#
#
# RUNNING  1206  iteration.
#
#
# RUNNING  1207  iteration.
#
#
# RUNNING  1208  iteration.
#
#
# RUNNING  1209  iteration.
#
#
# RUNNING  1210  iteration.
#
#
# RUNNING  1211  iteration.
#
#
# RUNNING  1212  iteration.
# RUNNING  1213  iteration.
#
#
# RUNNING  1214  iteration.
#
#
# RUNNING  1215  iteration.
#
#
# RUNNING  1216  iteration.
#
#
# RUNNING  1217  iteration.
#
#
# RUNNING  1218  iteration.
#
#
# RUNNING  1219  iteration.
#
#
# RUNNING  1220  iteration.
#
#
# RUNNING  1221  iteration.
#
#
# RUNNING  1222  iteration.
#
#
# RUNNING  1223  iteration.
#
#
# RUNNING  1224  iteration.
#
#
# RUNNING  1225  iteration.
#
#
# RUNNING  1226  iteration.
#
#
# RUNNING  1227  iteration.
#
#
# RUNNING  1228  iteration.
#
#
# RUNNING  1229  iteration.
#
#
# RUNNING  1230  iteration.
#
#
# RUNNING  1231  iteration.
#
#
# RUNNING  1232  iteration.
#
#
# RUNNING  1233  iteration.
#
#
# RUNNING  1234  iteration.
#
#
# RUNNING  1235  iteration.
#
#
# RUNNING  1236  iteration.
#
#
# RUNNING  1237  iteration.
#
#
# RUNNING  1238  iteration.
#
#
# RUNNING  1239  iteration.
#
#
# RUNNING  1240  iteration.
#
#
# RUNNING  1241  iteration.
#
#
# RUNNING  1242  iteration.
#
#
# RUNNING  1243  iteration.
#
#
# RUNNING  1244  iteration.
#
#
# RUNNING  1245  iteration.
#
#
# RUNNING  1246  iteration.
#
#
# RUNNING  1247  iteration.
#
#
# RUNNING  1248  iteration.
#
#
# RUNNING  1249  iteration.
#
#
# RUNNING  1250  iteration.
#
#
# RUNNING  1251  iteration.
#
#
# RUNNING  1252  iteration.
#
#
# RUNNING  1253  iteration.
#
#
# RUNNING  1254  iteration.
#
#
# RUNNING  1255  iteration.
#
#
# RUNNING  1256  iteration.
#
#
# RUNNING  1257  iteration.
#
#
# RUNNING  1258  iteration.
#
#
# RUNNING  1259  iteration.
#
#
# RUNNING  1260  iteration.
#
#
# RUNNING  1261  iteration.
#
#
# RUNNING  1262  iteration.
#
#
# RUNNING  1263  iteration.
#
#
# RUNNING  1264  iteration.
#
#
# RUNNING  1265  iteration.
#
#
# RUNNING  1266  iteration.
#
#
# RUNNING  1267  iteration.
#
#
# RUNNING  1268  iteration.
#
#
# RUNNING  1269  iteration.
#
#
# RUNNING  1270  iteration.
#
#
# RUNNING  1271  iteration.
#
#
# RUNNING  1272  iteration.
#
#
# RUNNING  1273  iteration.
#
#
# RUNNING  1274  iteration.
#
#
# RUNNING  1275  iteration.
#
#
# RUNNING  1276  iteration.
#
#
# RUNNING  1277  iteration.
#
#
# RUNNING  1278  iteration.
#
#
# RUNNING  1279  iteration.
#
#
# RUNNING  1280  iteration.
#
#
# RUNNING  1281  iteration.
#
#
# RUNNING  1282  iteration.
#
#
# RUNNING  1283  iteration.
#
#
# RUNNING  1284  iteration.
#
#
# RUNNING  1285  iteration.
#
#
# RUNNING  1286  iteration.
#
#
# RUNNING  1287  iteration.
#
#
# RUNNING  1288  iteration.
#
#
# RUNNING  1289  iteration.
#
#
# RUNNING  1290  iteration.
#
#
# RUNNING  1291  iteration.
#
#
# RUNNING  1292  iteration.
#
#
# RUNNING  1293  iteration.
#
#
# RUNNING  1294  iteration.
#
#
# RUNNING  1295  iteration.
#
#
# RUNNING  1296  iteration.
#
#
# RUNNING  1297  iteration.
#
#
# RUNNING  1298  iteration.
#
#
# RUNNING  1299  iteration.
#
#
# RUNNING  1300  iteration.
#
#
# RUNNING  1301  iteration.
#
#
# RUNNING  1302  iteration.
#
#
# RUNNING  1303  iteration.
#
#
# RUNNING  1304  iteration.
#
#
# RUNNING  1305  iteration.
#
#
# RUNNING  1306  iteration.
#
#
# RUNNING  1307  iteration.
#
#
# RUNNING  1308  iteration.
#
#
# RUNNING  1309  iteration.
#
#
# RUNNING  1310  iteration.
#
#
# RUNNING  1311  iteration.
#
#
# RUNNING  1312  iteration.
#
#
# RUNNING  1313  iteration.
#
#
# RUNNING  1314  iteration.
#
#
# RUNNING  1315  iteration.
#
#
# RUNNING  1316  iteration.
#
#
# RUNNING  1317  iteration.
#
#
# RUNNING  1318  iteration.
#
#
# RUNNING  1319  iteration.
#
#
# RUNNING  1320  iteration.
#
#
# RUNNING  1321  iteration.
#
#
# RUNNING  1322  iteration.
#
#
# RUNNING  1323  iteration.
#
#
# RUNNING  1324  iteration.
#
#
# RUNNING  1325  iteration.
#
#
# RUNNING  1326  iteration.
#
#
# RUNNING  1327  iteration.
#
#
# RUNNING  1328  iteration.
#
#
# RUNNING  1329  iteration.
#
#
# RUNNING  1330  iteration.
#
#
# RUNNING  1331  iteration.
#
#
# RUNNING  1332  iteration.
#
#
# RUNNING  1333  iteration.
#
#
# RUNNING  1334  iteration.
#
#
# RUNNING  1335  iteration.
#
#
# RUNNING  1336  iteration.
#
#
# RUNNING  1337  iteration.
#
#
# RUNNING  1338  iteration.
#
#
# RUNNING  1339  iteration.
#
#
# RUNNING  1340  iteration.
#
#
# RUNNING  1341  iteration.
#
#
# RUNNING  1342  iteration.
#
#
# RUNNING  1343  iteration.
#
#
# RUNNING  1344  iteration.
#
#
# RUNNING  1345  iteration.
#
#
# RUNNING  1346  iteration.
#
#
# RUNNING  1347  iteration.
#
#
# RUNNING  1348  iteration.
#
#
# RUNNING  1349  iteration.
#
#
# RUNNING  1350  iteration.
#
#
# RUNNING  1351  iteration.
#
#
# RUNNING  1352  iteration.
#
#
# RUNNING  1353  iteration.
#
#
# RUNNING  1354  iteration.
#
#
# RUNNING  1355  iteration.
#
#
# RUNNING  1356  iteration.
#
#
# RUNNING  1357  iteration.
#
#
# RUNNING  1358  iteration.
#
#
# RUNNING  1359  iteration.
#
#
# RUNNING  1360  iteration.
#
#
# RUNNING  1361  iteration.
#
#
# RUNNING  1362  iteration.
#
#
# RUNNING  1363  iteration.
#
#
# RUNNING  1364  iteration.
#
#
# RUNNING  1365  iteration.
#
#
# RUNNING  1366  iteration.
#
#
# RUNNING  1367  iteration.
#
#
# RUNNING  1368  iteration.
#
#
# RUNNING  1369  iteration.
#
#
# RUNNING  1370  iteration.
#
#
# RUNNING  1371  iteration.
#
#
# RUNNING  1372  iteration.
#
#
# RUNNING  1373  iteration.
#
#
# RUNNING  1374  iteration.
#
#
# RUNNING  1375  iteration.
#
#
# RUNNING  1376  iteration.
#
#
# RUNNING  1377  iteration.
#
#
# RUNNING  1378  iteration.
#
#
# RUNNING  1379  iteration.
#
#
# RUNNING  1380  iteration.
#
#
# RUNNING  1381  iteration.
#
#
# RUNNING  1382  iteration.
#
#
# RUNNING  1383  iteration.
#
#
# RUNNING  1384  iteration.
#
#
# RUNNING  1385  iteration.
#
#
# RUNNING  1386  iteration.
#
#
# RUNNING  1387  iteration.
#
#
# RUNNING  1388  iteration.
#
#
# RUNNING  1389  iteration.
#
#
# RUNNING  1390  iteration.
#
#
# RUNNING  1391  iteration.
#
#
# RUNNING  1392  iteration.
#
#
# RUNNING  1393  iteration.
#
#
# RUNNING  1394  iteration.
#
#
# RUNNING  1395  iteration.
#
#
# RUNNING  1396  iteration.
#
#
# RUNNING  1397  iteration.
#
#
# RUNNING  1398  iteration.
#
#
# RUNNING  1399  iteration.
#
#
# RUNNING  1400  iteration.
#
#
# RUNNING  1401  iteration.
#
#
# RUNNING  1402  iteration.
#
#
# RUNNING  1403  iteration.
#
#
# RUNNING  1404  iteration.
#
#
# RUNNING  1405  iteration.
#
#
# RUNNING  1406  iteration.
#
#
# RUNNING  1407  iteration.
#
#
# RUNNING  1408  iteration.
#
#
# RUNNING  1409  iteration.
#
#
# RUNNING  1410  iteration.
#
#
# RUNNING  1411  iteration.
#
#
# RUNNING  1412  iteration.
#
#
# RUNNING  1413  iteration.
#
#
# RUNNING  1414  iteration.
#
#
# RUNNING  1415  iteration.
#
#
# RUNNING  1416  iteration.
#
#
# RUNNING  1417  iteration.
#
#
# RUNNING  1418  iteration.
#
#
# RUNNING  1419  iteration.
#
#
# RUNNING  1420  iteration.
#
#
# RUNNING  1421  iteration.
#
#
# RUNNING  1422  iteration.
#
#
# RUNNING  1423  iteration.
#
#
# RUNNING  1424  iteration.
#
#
# RUNNING  1425  iteration.
#
#
# RUNNING  1426  iteration.
#
#
# RUNNING  1427  iteration.
#
#
# RUNNING  1428  iteration.
#
#
# RUNNING  1429  iteration.
#
#
# RUNNING  1430  iteration.
#
#
# RUNNING  1431  iteration.
#
#
# RUNNING  1432  iteration.
#
#
# RUNNING  1433  iteration.
#
#
# RUNNING  1434  iteration.
#
#
# RUNNING  1435  iteration.
#
#
# RUNNING  1436  iteration.
#
#
# RUNNING  1437  iteration.
#
#
# RUNNING  1438  iteration.
#
#
# RUNNING  1439  iteration.
#
#
# RUNNING  1440  iteration.
#
#
# RUNNING  1441  iteration.
#
#
# RUNNING  1442  iteration.
#
#
# RUNNING  1443  iteration.
#
#
# RUNNING  1444  iteration.
#
#
# RUNNING  1445  iteration.
#
#
# RUNNING  1446  iteration.
#
#
# RUNNING  1447  iteration.
#
#
# RUNNING  1448  iteration.
#
#
# RUNNING  1449  iteration.
#
#
# RUNNING  1450  iteration.
#
#
# RUNNING  1451  iteration.
#
#
# RUNNING  1452  iteration.
#
#
# RUNNING  1453  iteration.
#
#
# RUNNING  1454  iteration.
#
#
# RUNNING  1455  iteration.
#
#
# RUNNING  1456  iteration.
#
#
# RUNNING  1457  iteration.
#
#
# RUNNING  1458  iteration.
#
#
# RUNNING  1459  iteration.
#
#
# RUNNING  1460  iteration.
#
#
# RUNNING  1461  iteration.
#
#
# RUNNING  1462  iteration.
#
#
# RUNNING  1463  iteration.
#
#
# RUNNING  1464  iteration.
#
#
# RUNNING  1465  iteration.
#
#
# RUNNING  1466  iteration.
#
#
# RUNNING  1467  iteration.
#
#
# RUNNING  1468  iteration.
#
#
# RUNNING  1469  iteration.
#
#
# RUNNING  1470  iteration.
#
#
# RUNNING  1471  iteration.
#
#
# RUNNING  1472  iteration.
#
#
# RUNNING  1473  iteration.
#
#
# RUNNING  1474  iteration.
#
#
# RUNNING  1475  iteration.
#
#
# RUNNING  1476  iteration.
#
#
# RUNNING  1477  iteration.
#
#
# RUNNING  1478  iteration.
#
#
# RUNNING  1479  iteration.
#
#
# RUNNING  1480  iteration.
#
#
# RUNNING  1481  iteration.
#
#
# RUNNING  1482  iteration.
#
#
# RUNNING  1483  iteration.
#
#
# RUNNING  1484  iteration.
#
#
# RUNNING  1485  iteration.
#
#
# RUNNING  1486  iteration.
#
#
# RUNNING  1487  iteration.
#
#
# RUNNING  1488  iteration.
#
#
# RUNNING  1489  iteration.
#
#
# RUNNING  1490  iteration.
#
#
# RUNNING  1491  iteration.
#
#
# RUNNING  1492  iteration.
#
#
# RUNNING  1493  iteration.
#
#
# RUNNING  1494  iteration.
#
#
# RUNNING  1495  iteration.
#
#
# RUNNING  1496  iteration.
#
#
# RUNNING  1497  iteration.
#
#
# RUNNING  1498  iteration.
#
#
# RUNNING  1499  iteration.
#
#
# RUNNING  1500  iteration.
# Total domain related links discovered: 4337

# %% [markdown]
# #### This function takes in a HTML page content, passes it to Beautiful soup, cleans it by removing all JS and CSS content and extracts only the relevant body content with the paragraphs. Returns the cleaned content.

# %%
def cleanHTMLData(requested):
    soup = BeautifulSoup(requested.content, "html.parser")
    
    for script in soup(["script", "style"]):
        script.extract()
    
    text = []
    paras = soup.find_all("p")
    
    for i in range(len(paras)):
        if paras[i].text != 'Advertisement' and paras[i] != 'Supported by':
            text.append(paras[i].text)

#     for script in soup(["script", "style"]):
#         script.extract()

#     HTML_text = soup.get_text()
    
    HTML_text = " ".join(text)
    
    return HTML_text

# %% [markdown]
# #### Following part of code takes every URL from the CSV file, requests its content and cleans it after Beautiful Soup and writes the cleaned content to a txt file for MR and analysis.

# %%
f1 = codecs.open("politics_US_CC.txt", "a+", encoding = 'utf-8')
# headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}

count = 0
rowCount = 0
with open ("politics_US_CC.csv", "r") as f:
    rowCount = len(f.readlines())
    
with open ("politics_US_CC.csv", "r") as f:
    reader = csv.reader(f)    
    row = next(reader)


    for i in range(rowCount):
        row = next(reader)
        res = row[0]
        
        print "\n\nCurrent Link:   ", res
        print "\nRequesting URL content"
        
        try:
            r = requests.get(res)
        except:
            continue

#         r = requests.get(res)

        content = cleanHTMLData(r)
        f1.write("\n" + content + "\n\n\n\n\n\n")
        count += 1

f1.close()
# Out:
# Current Link:    https://www.huffpost.com
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2F
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2F
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jeff-bezos-national-enquirer-michael-sanchez_n_5c904a40e4b04ed2c1ad9825
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/steve-king-civil-war-graphic_n_5c8ef5b9e4b03e83bdc25c86
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/kellyanne-conway-new-zealand-killer-white-supremacy-manifesto_n_5c8fa75fe4b0d7f6b0f61cc9
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-raids-military_n_5c901777e4b0d50544fee195
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-foundation-ny-ag-fine_n_5c8ef7bbe4b0db7da9f4cf3a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/utrecht-shooting-dutch-tram_n_5c8f8800e4b0db7da9f5bc73
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/white-nationalists-military-identity-evropa_n_5c8ab70ae4b0d7f6b0f1094b
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-white-nationalism-poll_n_5c90026ce4b0d50544fed11a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/ariel-edwardslevy
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jair-bolsonaro-brazil-steve-bannon-olavo-de-carvalho_n_5c8fb5a1e4b0d50544fe2318
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/travis-waldron
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/whoopi-goldberg-returns-the-view_n_5c8fcffde4b071a25a853872
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/amy-russo
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/meghan-mccain-donald-trump-pathetic_n_5c8feb82e4b0d50544fe9c2c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/rebecca-shapiro
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/victorias-secret-swim_l_5c8fcff0e4b0d50544fe64c1
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/jamie-feldman
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/stephen-colbert-jeanine-pirro-racist_n_5c904176e4b071a25a85c88f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/ed-mazza
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/leslie-jones-donald-trump_n_5c90448de4b0d50544fef528
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/phoenix-mosque-new-zealand-shooting_n_5c8faf2ee4b04ed2c1acbccc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/hayley-miller
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/florida-felony-disenfranchisement-bill_n_5c901a9de4b04ed2c1ad8366
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/sam-levine
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mike-pompeo-religious-freedom-faith-based-media_n_5c9020e2e4b071a25a85b87e
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/mary-s-papenfuss
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/viral-twitter-thread-hilariously-details-how-two-dogs-and-a-cat-broke-into-a-home_n_5c8fbdaee4b04ed2c1acddb0
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/us-news
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/elyse-wanshel
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/democrats-fbi-investigation-cindy-yang-trump-china_n_5c903ac7e4b0d50544fef24c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/sanjana-karanth
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/julia-roberts-pretty-woman-thoughts_n_5c8fe950e4b071a25a856cd1
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/entertainment
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/curtis-wong
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/devin-nunes-twitter-lawsuit-shadow-banning_n_5c9024cee4b071a25a85b9a9
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/antonia-blumberg
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/donald-trump-donate-homeland-security_n_5c9024dee4b0d50544fee504
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/david-moye
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/donna-brazile-fox-news_n_5c900d9ce4b0d50544fedb72
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/media
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/district-attorney-probes-horse-racetrack_n_5c8fa9d2e4b0db7da9f60c56
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/nina-golgowski
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/dna-arrest-hawlett-beasley-murder_n_5c8f9077e4b03e83bdc36a3d
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/crime
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/warner-bros-ceo-kevin-tsujihara-resigns-sexual-scandal_n_5c8fe8e4e4b04ed2c1ad3888
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/cole-delbyck
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/static/about-us
#
# Requesting URL content
#
#
# Current Link:    https://www.oath.com/brands/huffpost/
#
# Requesting URL content
#
#
# Current Link:    https://adinfo.aol.com/about-our-ads/
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/static/contact-us
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/syndication
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/static/faq
#
# Requesting URL content
#
#
# Current Link:    https://www.oath.com/careers/job-openings?q=&jobDepartment=&jobBrand=huff+post&jobCity=
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/archive/
#
# Requesting URL content
#
#
# Current Link:    https://policies.oath.com/us/en/oath/terms/otos/index.html
#
# Requesting URL content
#
#
# Current Link:    https://policies.oath.com/us/en/oath/privacy/index.html
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/static/comment-policy
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/topic/press-room
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com?country=US
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.ca?country=CA
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.co.uk?country=UK
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.com.au?country=AU
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpostbrasil.com?country=BR
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.de?country=DE
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.es?country=ES
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.fr?country=FR
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.gr?country=GR
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.in?country=IN
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.it?country=IT
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.jp?country=JP
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.kr?country=KR
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpostmaghreb.com?country=MG
#
# Requesting URL content
#
#
# Current Link:    https://quebec.huffingtonpost.ca?country=QC
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/world-news
#
# Requesting URL content
# Current Link:    https://www.huffpost.com/impact/business
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/impact/green
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/health
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/impact/topic/social-justice
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/topic/us-congress
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/topic/donald-trump
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/topic/2018-elections
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/news/topic/extremism
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/arts
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/celebrity
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/tv
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/voices/
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/voices/queer-voices
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/voices/women
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/voices/black-voices
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/voices/latino-voices
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/voices/asian-voices
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/huffpost-personal
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/video
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/style
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/taste
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/parents
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/travel
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/topic/finds
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/healthy-living
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/relationships
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/money
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/huffpost-home
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/life/worklife
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/impact/topic/project-zero
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/impact/topic/this-new-world
#
# Requesting URL content
#
#
# Current Link:    https://highline.huffingtonpost.com/
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/feature/listen-to-america
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/topic/podcasts
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/impact/topic/purpose-profit
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/newsletters
#
# Requesting URL content
#
#
# Current Link:    https://facebook.com/HuffPost
#
# Requesting URL content
#
#
# Current Link:    https://twitter.com/HuffPost
#
# Requesting URL content
#
#
# Current Link:    https://instagram.com/HuffPost
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/teachers-shot-active-shooter-drill_n_5c93fc99e4b0a6329e142b5a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/new-zealand-muslim-prayer-terrorism_n_5c942bf7e4b01ebeef0d4974
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/update-5-u-s-imposes-first-new-north-korea-sanctions-since-failed-summit_n_5c947dd4e4b01ebeef0d7f47
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/john-roberts-obamacare-changed-mind_n_5c94501ee4b0a6329e14b663
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/robert-mueller-report-drop-speculation_n_5c9476f2e4b01ebeef0d74bd
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jimmy-carter-longest-living-president_n_5c939768e4b01b140d367789
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/alexandria-ocasio-cortez-seth-meyers-fox-news_n_5c948eefe4b057f733092ee6
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/general-robert-neller-border-unacceptable-risk_n_5c947d69e4b057f7330910cc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/elijah-cummings-whatsapp-jared-kushner-foreign-leaders_n_5c94292ce4b0a6329e149aac
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jennifer-lopez-alex-rodriguez-barack-obama_n_5c948118e4b01ebeef0d83b9
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/carla-baranauckas
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/alexandria-ocasio-cortez-hillary-clinton-jared-kushner_n_5c944b75e4b057f73308f032
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/college-admissions-scandal-lori-loughlin-old-interview_n_5c947ea4e4b0a6329e14d36c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/lee-moran
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/how-to-host-a-dinner-party_l_5c8aac88e4b0db7da9f0d059
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/kelly-paige
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/seth-meyers-glenn-beck-donald-trump_n_5c948747e4b01ebeef0d8e9a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-john-mccain-make-it-stop_n_5c93fc8ee4b0a6329e142b58
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/sara-boboltz
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/khizr-khan-donald-trump-john-mccain-attacks_n_5c9498cee4b0a6329e14ff88
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/washington-national-cathedral-john-mccain-funeral-trump_n_5c93fa18e4b0a6329e14249e
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/ryan-zinke-tribal-casino-connecticut-approval_n_5c93f339e4b057f733085017
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/chris-dangelo
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/donald-trump-john-mccain-bob-kerrey-vietnam-x-ray-bone-spurs_n_5c933db2e4b0d952b223753a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/donald-trump-jr-2024-campaign-ad-jimmy-kimmel_n_5c949112e4b01ebeef0d9e38
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entertainment/comedy
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mike-huckabee-beto-orourke_n_5c943ab5e4b01ebeef0d4ecc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mountain-lions-extinction-wildlife-corridors_n_5c945693e4b057f73308fa56
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mariah-bell-lim-eun-soo-skate-incident_n_5c93d1c8e4b093dbd819585a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/sports
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/emilia-clarke-aneurysms-game-of-thrones_n_5c93c32fe4b088a7df055dcc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jordan-peele-us_n_5c8a7db8e4b0450ddae87f04
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/taryn-finley
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/save-money-on-food-kids_l_5c940081e4b057f733086f5f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mueller-report-trump-russia_n_5c6da126e4b0f40774cb6fea
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/robert-mueller-no-more-indictments-russia-investigation_n_5c955a74e4b01ebeef0f479e
#
# Requesting URL content
# Current Link:    https://www.huffpost.com/entry/trump-special-counsel-robert-mueller-investigation_n_5c5c9891e4b03afe8d65ada3
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/democrats-immediate-release-mueller-report_n_5c95524ee4b01ebeef0f3b74
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-investigation-campaign-finance-charges_n_5c952574e4b01ebeef0eface
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/rupert-murdoch-executive-quit-fox-news-anti-immigrant-islamophobic-coverage_n_5c94ca5de4b0a6329e155dec
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/joe-biden-stacey-abrams_n_5c952b88e4b0a6329e16565f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/beto-orourke-bernie-sanders-democratic-fundraising-primary_n_5c941176e4b01ebeef0d1cae
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/daniel-marans
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/dccc-promises-to-blacklist-firms-that-work-with-candidates-challenging-incumbents_n_5c95126ae4b01ebeef0ec3ae
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/priyanka-chopra-meghan-markle-friendship-feud_n_5c94fa8fe4b01ebeef0e7edd
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/carly-ledbetter
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/elizabeth-holmes-office-employees_l_5c92abe3e4b01b140d351b6f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/monica-torres
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mueller-report-gifs-reactions_n_5c955838e4b0a6329e16938f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jennifer-garner-reese-witherspoon-birthday_n_5c95385be4b057f7330a9e71
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/roseanne-barr-sara-gilbert-tweet-ruined-career_n_5c952f46e4b01ebeef0f0929
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/the-latest-trump-lawyers-want-early-look-at-mueller-report_n_5c956446e4b0a6329e16a429
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/republicans-mueller-report-trump-russia_n_5c9564b3e4b057f7330add76
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/sarah-grossman
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/connecticut-ella-briggs-kid-governor-lesbian-president_n_5c950965e4b0a6329e15f504
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/stephen-moore-federal-reserve-trump-climate-change-obamacare_n_5c953441e4b0a6329e166035
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/jonathan-cohn
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/michael-bloomberg-joe-biden-apology-tour_n_5c953b44e4b057f7330aa3cb
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/sydney-aiello-parkland-shooting-survivor-suicide_n_5c95107de4b057f7330a4938
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/rudolph-giuliani-wikipedia-twitter_n_5c951beee4b0a6329e1631f2
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/deaf-transgender-actor-chella-man-titans-jericho_n_5c951a90e4b01ebeef0ede54
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/kimberly-yam
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/donald-trump-queen-esther-mike-pompeo_n_5c95254be4b01ebeef0efa65
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/carol-kuruvilla
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/debit-vs-credit-card-fraud_l_5c952583e4b01ebeef0efb0f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/casey-bond
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/fox-laura-ingraham-free-speech-nyu_n_5c94f925e4b01ebeef0e79ad
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/ryan-grenoble
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/dashcam-video-teen-beating-by-west-virginia-police-during-traffic-stop_n_5c94f2dee4b0a6329e15bcca
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-bolsonaro-brazil-usa-machismo_n_5c923dbce4b0dbf58e468b6b
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/kentucky-governor-matt-bevin-chickenpox_n_5c92861be4b08c4fec33a18f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/devin-nunes-cow-twitter-followers_n_5c925039e4b0dbf58e46be21
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/spy-cameras-hotels-south-korea_n_5c92821be4b01b140d34c758
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-retweets-qanon-conspiracy-theorist_n_5c924324e4b0f7ed945e6b25
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/olivia-munn-warner-bros-ceo-kevin-tsujihara-sexual-misconduct_n_5c928c07e4b0d952b222b261
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/johnny-isakson-donald-trump-john-mccain_n_5c9264d0e4b08c4fec334d1d
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/faith-vander-voort-interior-2017-podcast-islamophobia_n_5c9100c6e4b04ed2c1af0760
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/rowaida-abdelaziz
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/eu-regulators-fine-google-1-49-billion-euros-1-68-billion-for-abusing-its-dominance-in-online-advertising_n_5c92306ce4b0f7ed945e3653
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/prince-harry-prince-william-feud_n_5c92523ce4b0f7ed945e92e6
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/kellyanne-conway-george-conway-donald-trump_n_5c928862e4b0d952b222ac32
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jay-z-library-of-congress-national-recording-registry_n_5c9270cfe4b0d952b22274d5
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/kimberley-richards
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/issey-miyake-elizabeth-holmes-black-turtleneck_l_5c925110e4b0dbf58e46bfcc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/julia-brucculieri
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jessica-simpson-third-child-birdie_n_5c9297f3e4b0d952b222c100
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jewish-cemetery-swastikas-fall-river-massachusetts_n_5c92406fe4b0f7ed945e603c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/marc-randazza-alex-jones-connecticut-judge_n_5c919bd6e4b0dbf58e459cf5
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/luke-obrien
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-isis-map-photoshop_n_5c92ac91e4b0d952b222f523
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/steve-harrington-stranger-things-trailer_n_5c92a6aae4b0d952b222ddb9
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/keanu-reeves-alex-winter-bill-ted-2020_n_5c929050e4b08c4fec33b462
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/why-the-first-drug-for-postpartum-depression-is-a-very-big-deal_l_5c92724de4b0d952b2227754
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/catherine-pearson
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/martha-mcsally-john-mccain-trump_n_5c92895be4b08c4fec33a72a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/dog-dead-air-france-cargo_n_5c928b4ce4b08c4fec33aa01
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/hilary-hanson
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/border-wall-stolen-tijuana-home-security_n_5c9291bbe4b08c4fec33b5f4
#
# Requesting URL content
# Current Link:    https://www.huffpost.com/entry/maryland-15-minimum-wage-bill_n_5c929006e4b0d952b222b9e5
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/machelle-hackney-abusive-youtube-channel_n_5c9225cfe4b0f7ed945e215f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/tomi-lahren-liberal-indoctrination-school_n_5c925740e4b0d952b2222e94
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/ron-dicker
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/beto-orourke-24-hours-fundraising-record_n_5c8f7d31e4b0d7f6b0f5b082
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/ilhan-omar-israel-palestine_n_5c8f7004e4b0db7da9f582e6
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/why-did-kamala-harris-let-herbalife-off-the-hook_n_5c8fab16e4b03e83bdc39a37
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/christopher-mathias
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/boeing-737-max-training-safety_n_5c8ee77de4b0db7da9f4c707
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/nick-visser
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/khloe-kardashian-defends-tristan-thompson_n_5c8faf0be4b0d50544fe181a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/kim-kardashian-psoriasis_n_5c8f9afce4b0db7da9f5f43f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/kate-middleton-prince-william-st-patricks-day_n_5c8fa6f6e4b03e83bdc393cd
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jim-carrey-new-zealand-trump_n_5c8f71a0e4b03e83bdc312e7
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/andrew-rannells-says-a-priest-forcibly-kissed-him-when-he-was-a-teenager_n_5c8f9f62e4b0d7f6b0f61128
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/alanna-vagianos
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jayme-closs-kiddnapper-jake-patterson_n_5c8f8d13e4b0db7da9f5d089
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/midwest-missouri-river-flood-iowa-nebraska_n_5c8f7e76e4b0db7da9f59e19
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/haloti-ngata-kilimanjaro_n_5c8fc17ee4b0d50544fe45ca
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/be-kind-please-rewind-oregon-blockbuster-is-last-on-earth_n_5c8fb7c9e4b071a25a84f9f5
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/section/weird-news
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/islamophobia-is-a-global-crisis-and-its-time-we-view-it-that-way_n_5c8e5867e4b0db7da9f48156
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/akbar-shahid-ahmed
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/nick-robinsearly
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/alexandria-ocasio-cortez-pushups_n_5c8f91f8e4b03e83bdc36ca5
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/dead-whale-plastic-phillipines_n_5c8f9b2ee4b0d7f6b0f6085d
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/good-movies-netflix-the-dirt_l_5c8faa8ae4b0d7f6b0f6218c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/todd-van-luling
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/disney-popcorn-buckets_l_5c8a9c64e4b0db7da9f0bd3f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/taylor-pittman
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/beth-leavel-the-prom-broadway-musical_n_5c7833c1e4b0d3a48b57e8e5
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/why-does-someone-fake-cancer_l_5c91322ce4b05d2b09550d7f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/kate-bratskeir
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-administration-pre-existing-conditions-court_n_5c999b91e4b0d42ce360169c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/nasa-female-spacewalk-spacesuit-size_n_5c99a614e4b074355549baeb
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mo-brooks-adolf-hitler-democrats-press-big-lie_n_5c994c91e4b0743555497620
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/new-jersey-right-to-die-bill_n_5c996a5ee4b074355549902b
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/kamala-harris-teacher-pay_n_5c993d51e4b074355549558a
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/chris-cuomo-trump-victory-lap_n_5c99b4aae4b0f7bfa1b5be2d
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/pete-buttigieg-pronounce_n_5c99b227e4b0f7bfa1b5bbbf
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/house-democrats-william-barr-mueller-report_n_5c9968bbe4b0f7bfa1b5887f
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/global-carbon-emissions-record-high-2018_n_5c9975cee4b0f7bfa1b59668
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/stephen-colbert-trump-apology_n_5c998622e4b074355549aa3c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jusuf-nurkic-leg-injury_n_5c99b85be4b0f7bfa1b5c1dc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/justin-bieber-music-break_n_5c99bbb0e4b074355549c8bd
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/stress-affects-skin_l_5c991662e4b0a6329e1a0996
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/us-doppelgangers-lupita-nyongo-madeline-hollander_n_5c98cbede4b01ebeef11f6bb
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/jacobs-matthew
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/felix-sater-donald-trump-trump-tower-moscow-lawsuit_n_5c997596e4b0f7bfa1b59647
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/mueller-report-congress-fallout_n_5c9972f3e4b0d42ce35ff9dc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/matt-fuller
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/trump-campaign-tv-producers-certain-guests_n_5c9956d7e4b07435554982fd
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/sarah-huckabee-sanders-mueller-march-madness-bracket-anger_n_5c99c637e4b0d42ce36031cf
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/preet-bharara-mueller-barr-trup-congress_n_5c999d92e4b0f7bfa1b5b279
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/rachel-maddow-donald-trump-special-counsel-15-question_n_5c99cddce4b0f7bfa1b5d6a4
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/james-corden-casting-suggestion-mueller-movie_n_5c99c98de4b074355549d438
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/jimmy-kimmel-mueller-mike-pence_n_5c99a7e5e4b074355549bb34
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/ruben-gallego-arizona-democrat-senate_n_5c994e0ce4b0d42ce35fd5bb
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/kevin-robillard
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/michael-avenatti-nike-ncaa-athletes_n_5c99387ae4b0743555494fbc
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/california-avocados-voluntarily-recalled-for-possible-health-risk_l_5c99c605e4b074355549d045
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/apple-card-review_l_5c994530e4b0f7bfa1b56792
#
# Requesting URL content
#
#
# Current Link:    https://www.huffingtonpost.com/archive
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Farchive%2F2019-03-22
#
# Requesting URL content
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Farchive%2F2019-03-22
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/zodiac-erogenous-zones-sexual-pleasure-astrology_l_5c93cab1e4b0e9efc8b59ab3
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/-brittany-wong
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/devincow-cowsuit-protest-fresno-event_n_5c940000e4b0a6329e142d67
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/carla-herreria
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/entry/oil-industry-climate_n_5c940962e4b0a6329e144e6c
#
# Requesting URL content
#
#
# Current Link:    https://www.huffpost.com/author/alexander-c-kaufman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-brittany-wong
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-brittany-wong
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-dr-joseph-horrigan
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-dr-joseph-horrigan
#
# Requesting URL content
#
#
# Current Link:    http://scuhealth.org/
#
# Requesting URL content
#
#
# Current Link:    http://www.scuhs.edu/
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-fernando-moralesde-la-cruz
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-fernando-moralesde-la-cruz
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/fmdelac
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-lily-karlin
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-lily-karlin
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/lilykarlin
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-sarah-bourassa
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F-sarah-bourassa
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/sabourassa
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F92martinmanuel-955
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2F92martinmanuel-955
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/fashionfysik
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fa-857
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fa-857
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/amol
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fa-lea-roth
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fa-lea-roth
#
# Requesting URL content
#
#
# Current Link:    http://www.timetospringup.org
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faakennedy3696-328
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faakennedy3696-328
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faamir-hussain
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faamir-hussain
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-585
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-585
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/aaronpackard
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-baker
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-baker
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/imaaronbaker
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-coleman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-coleman
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/arcwrites
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-glantz
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-glantz
#
# Requesting URL content
#
#
# Current Link:    http://news.newamericamedia.org/news/
#
# Requesting URL content
#
#
# Current Link:    http://www.amazon.com/America-Lost-Iraq-Aaron-Glantz/dp/1585424870/ref=ntt_at_ep_dpi_2
#
# Requesting URL content
#
#
# Current Link:    http://www.amazon.com/War-Comes-Home-Washingtons-Americas/dp/0520256123/ref=sr_1_1?ie=UTF8&s=books&qid=1251389100&sr=8-1
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-rhodes
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-rhodes
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/Rhodesaaron
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-sankin
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-sankin
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-taylor
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-taylor
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/aarondtaylor
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-weiss
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-weiss
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/aweiss
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-zelinsky
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaron-zelinsky
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaronn-113
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faaronn-113
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/ABNiederhelman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-heugel
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-heugel
#
# Requesting URL content
#
#
# Current Link:    http://www.abbyhasissues.com
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-maxman
#
# Requesting URL content
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-maxman
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/abbymaxman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-miller-king-216
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-miller-king-216
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/abbykingwriter
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-smith-rumsey
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-smith-rumsey
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-sugar
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-sugar
#
# Requesting URL content
#
#
# Current Link:    http://www.playout-underwear.com/
#
# Requesting URL content
#
#
# Current Link:    http://www.playout-underwear.com
#
# Requesting URL content
#
#
# Current Link:    http://twitter.com/PlayOutNYC
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-tegnelia
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabby-tegnelia
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/abbytegnelia
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabdhysn-350
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabdhysn-350
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/abyasun
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabena-hutchful
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabena-hutchful
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/@freadomfighter
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabgutman-362
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabgutman-362
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/abgutman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabi-cotler-oroarty
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabi-cotler-oroarty
#
# Requesting URL content
#
#
# Current Link:    https://www.facebook.com/AbiCotler
#
# Requesting URL content
#
#
# Current Link:    http://www.abicotleroroarty.com/
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabi-fedorovsky
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabi-fedorovsky
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabigail-abesamis
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabigail-abesamis
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabigail-williams
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabigail-williams
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/gabigailgilliam
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabigail-wise
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabigail-wise
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabpalumbo-686
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabpalumbo-686
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/InsideAdmission
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabraham-paulos
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabraham-paulos
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabraham-r-wagner
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabraham-r-wagner
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/abe1wagner
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabrahamjonasfroman-593
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabrahamjonasfroman-593
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/DrAJFroman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabrego-369
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fabrego-369
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/AbregoLeisy
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faburyk-656
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Faburyk-656
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fachanin-508
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fachanin-508
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Facummins03-762
#
# Requesting URL content
#
#
# ...
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanita-h-clayton-md
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanita-h-clayton-md
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanita-sinha
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanita-sinha
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanjali-sareen
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanjali-sareen
#
# Requesting URL content
# Current Link:    https://www.twitter.com/AnjaliSareen
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanjhula-345
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanjhula-345
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/Anjhula
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanju-bhargava
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanju-bhargava
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-brenoff
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-brenoff
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/AnnBrenoff
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-coyle-rn
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-coyle-rn
#
# Requesting URL content
#
#
# Current Link:    http://www.amazingnurses.com/
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-gentry
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-gentry
#
# Requesting URL content
#
#
# Current Link:    http://www.realfood.com
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-imse
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-imse
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-jones
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-jones
#
# Requesting URL content
#
#
# Current Link:    http://www.amazon.com/dp/1608463710/ref=nosim/?tag=tomdispatch-20
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-lee
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-lee
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-medlock
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-medlock
#
# Requesting URL content
#
#
# Current Link:    http://www.giraffe.org/
#
# Requesting URL content
#
#
# Current Link:    http://www.giraffe.org/ed.html
#
# Requesting URL content
#
#
# Current Link:    http://www.giraffe.org/blog/
#
# Requesting URL content
#
#
# Current Link:    http://www.annmedlock.com/news/index.htm
#
# Requesting URL content
#
#
# Current Link:    http://www.annmedlock.com
#
# Requesting URL content
#
#
# Current Link:    http://www.annmedlock.com/works/browse.htm
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-oleary
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-oleary
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-paisley-chandler
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-paisley-chandler
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/apschandler
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-veneman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fann-veneman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-441
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-441
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/annabdavid
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-almendrala
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-almendrala
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/twitter.com/annaalmendrala
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-brones
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-brones
#
# Requesting URL content
#
#
# Current Link:    http://annabrones.wordpress.com/
#
# Requesting URL content
#
#
# Current Link:    http://foodieunderground.com/
#
# Requesting URL content
#
#
# Current Link:    http://foodieunderground.com/culinary-cyclist
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-burger
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-burger
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-clark
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-clark
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/annaclark
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-johansson
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-johansson
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/number1annajo
#
# Requesting URL content
#
#
# Current Link:    https://twitter.com/number1annajo
#
# Requesting URL content
#
#
# Current Link:    https://www.linkedin.com/pub/anna-johansson/71/222/a74
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-kegler-964
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-kegler-964
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/annakegler
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-shen
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-shen
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/annashen
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-sher-simon
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-sher-simon
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-staver
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-staver
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-susman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-susman
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-szymanski
#
# Requesting URL content
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanna-szymanski
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/three_guineas
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannabelle-buggle
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannabelle-buggle
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannaleahy-849
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannaleahy-849
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/GenerationSpace
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannasowinski-429
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannasowinski-429
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/stopmed_wt_gain
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-291
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-291
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/anneloehr
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-hidalgo
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-hidalgo
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/Anne_Hidalgo
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-maxfield
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-maxfield
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/alocavore
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-mosle-264
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-mosle-264
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/AspenAscend
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-naylor
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-naylor
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/Anne4Joy
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-ravanona
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanne-ravanona
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/anneravanona
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanneli-rufus
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanneli-rufus
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/annelirufus
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannemargaretdaniel-167
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannemargaretdaniel-167
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/venetianblonde
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannemarie-strehl
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannemarie-strehl
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/travel_brain
#
# Requesting URL content
#
#
# Current Link:    http://travelonthebrain.net/
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannie-cushing
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannie-cushing
#
# Requesting URL content
#
#
# Current Link:    https://twitter.com/anniecushing
#
# Requesting URL content
#
#
# Current Link:    http://www.linkedin.com/in/anniecushing
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Forigin-production.www.huffpost.com%2Fauthor%2Fannie-shattuck
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Forigin-production.www.huffpost.com%2Fauthor%2Fannie-shattuck
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannieannieannie-423
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fannieannieannie-423
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/annieannieannie
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanoa-changa
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanoa-changa
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/TheWayWithAnoa
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanoka-primrose-abeyrathne
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanoka-primrose-abeyrathne
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/login?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanonymous
#
# Requesting URL content
#
#
# Current Link:    https://oidc.huffpost.com/create?dest=https%3A%2F%2Fwww.huffpost.com%2Fauthor%2Fanonymous
#
# Requesting URL content
#
#
# Current Link:    https://www.twitter.com/jordaine_chatt
#
# Requesting URL content
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-34-cf57e944c8b8> in <module>()
#      13
#      14     for i in range(rowCount):
# ---> 15         row = next(reader)
#      16         res = row[0]
#      17
#
# StopIteration:
